# %%
import random

# Expanded questions for different topics and difficulty levels
quiz_data = {
    'Math': {
        'easy': [
            {'question': 'What is 2 + 2?', 'options': ['3', '4', '5'], 'answer': '4'},
            {'question': 'What is 5 - 3?', 'options': ['1', '2', '3'], 'answer': '2'},
            {'question': 'What is 10 / 2?', 'options': ['3', '4', '5'], 'answer': '5'},
            {'question': 'What is 7 + 6?', 'options': ['12', '13', '14'], 'answer': '13'},
            {'question': 'What is 9 - 4?', 'options': ['3', '4', '5'], 'answer': '5'},
        ],
        'medium': [
            {'question': 'What is 12 * 2?', 'options': ['22', '24', '26'], 'answer': '24'},
            {'question': 'What is 15 / 3?', 'options': ['3', '4', '5'], 'answer': '5'},
            {'question': 'What is 8 * 7?', 'options': ['54', '56', '58'], 'answer': '56'},
            {'question': 'What is 81 / 9?', 'options': ['8', '9', '10'], 'answer': '9'},
            {'question': 'What is 14 * 4?', 'options': ['54', '56', '60'], 'answer': '56'},
        ],
        'hard': [
            {'question': 'What is 25^2?', 'options': ['625', '650', '675'], 'answer': '625'},
            {'question': 'What is the square root of 144?', 'options': ['10', '12', '14'], 'answer': '12'},
            {'question': 'What is 13^2?', 'options': ['169', '144', '121'], 'answer': '169'},
            {'question': 'What is 22 * 19?', 'options': ['418', '396', '420'], 'answer': '418'},
            {'question': 'What is 81^(1/2)?', 'options': ['7', '8', '9'], 'answer': '9'},
        ],
    },
    'Science': {
        'easy': [
            {'question': 'What planet is closest to the Sun?', 'options': ['Mars', 'Mercury', 'Venus'], 'answer': 'Mercury'},
            {'question': 'What gas do plants breathe in?', 'options': ['Oxygen', 'Carbon Dioxide', 'Nitrogen'], 'answer': 'Carbon Dioxide'},
            {'question': 'What is H2O?', 'options': ['Water', 'Oxygen', 'Hydrogen'], 'answer': 'Water'},
            {'question': 'What gas do humans breathe out?', 'options': ['Oxygen', 'Carbon Dioxide', 'Nitrogen'], 'answer': 'Carbon Dioxide'},
            {'question': 'What is the center of an atom called?', 'options': ['Electron', 'Neutron', 'Nucleus'], 'answer': 'Nucleus'},
        ],
        'medium': [
            {'question': 'What is the chemical symbol for Iron?', 'options': ['Ir', 'Fe', 'In'], 'answer': 'Fe'},
            {'question': 'What is the process by which plants make their food?', 'options': ['Respiration', 'Photosynthesis', 'Transpiration'], 'answer': 'Photosynthesis'},
            {'question': 'What is the most abundant gas in the Earth’s atmosphere?', 'options': ['Oxygen', 'Nitrogen', 'Carbon Dioxide'], 'answer': 'Nitrogen'},
            {'question': 'What is the hardest natural substance on Earth?', 'options': ['Gold', 'Iron', 'Diamond'], 'answer': 'Diamond'},
            {'question': 'What is the chemical symbol for Sodium?', 'options': ['So', 'Na', 'S'], 'answer': 'Na'},
        ],
        'hard': [
            {'question': 'What is the speed of light?', 'options': ['299,792 km/s', '150,000 km/s', '400,000 km/s'], 'answer': '299,792 km/s'},
            {'question': 'Who developed the theory of relativity?', 'options': ['Isaac Newton', 'Albert Einstein', 'Galileo Galilei'], 'answer': 'Albert Einstein'},
            {'question': 'What is the powerhouse of the cell?', 'options': ['Nucleus', 'Mitochondria', 'Ribosome'], 'answer': 'Mitochondria'},
            {'question': 'What is the chemical symbol for Gold?', 'options': ['Go', 'Au', 'Ag'], 'answer': 'Au'},
            {'question': 'What is the second most abundant element in the Earth’s crust?', 'options': ['Silicon', 'Aluminum', 'Iron'], 'answer': 'Silicon'},
        ],
    },
    'History': {
        'easy': [
            {'question': 'Who was the first President of the United States?', 'options': ['Abraham Lincoln', 'George Washington', 'Thomas Jefferson'], 'answer': 'George Washington'},
            {'question': 'In which year did the Titanic sink?', 'options': ['1912', '1905', '1920'], 'answer': '1912'},
            {'question': 'Who wrote the Declaration of Independence?', 'options': ['George Washington', 'Thomas Jefferson', 'John Adams'], 'answer': 'Thomas Jefferson'},
            {'question': 'Who was the Queen of England during the Spanish Armada?', 'options': ['Queen Elizabeth I', 'Queen Victoria', 'Queen Mary I'], 'answer': 'Queen Elizabeth I'},
            {'question': 'In what year did World War I begin?', 'options': ['1912', '1914', '1918'], 'answer': '1914'},
        ],
        'medium': [
            {'question': 'Who discovered America?', 'options': ['Christopher Columbus', 'Leif Erikson', 'Ferdinand Magellan'], 'answer': 'Christopher Columbus'},
            {'question': 'What was the name of the ship on which the Pilgrims traveled to America?', 'options': ['The Mayflower', 'The Santa Maria', 'The Beagle'], 'answer': 'The Mayflower'},
            {'question': 'Who was the first emperor of Rome?', 'options': ['Julius Caesar', 'Augustus', 'Nero'], 'answer': 'Augustus'},
            {'question': 'Which war was fought between the North and South regions in the United States?', 'options': ['Revolutionary War', 'Civil War', 'War of 1812'], 'answer': 'Civil War'},
            {'question': 'Who was the leader of the Soviet Union during World War II?', 'options': ['Vladimir Lenin', 'Joseph Stalin', 'Nikita Khrushchev'], 'answer': 'Joseph Stalin'},
        ],
        'hard': [
            {'question': 'Who was the Prime Minister of the United Kingdom during World War II?', 'options': ['Winston Churchill', 'Neville Chamberlain', 'Clement Attlee'], 'answer': 'Winston Churchill'},
            {'question': 'What year did the Berlin Wall fall?', 'options': ['1987', '1989', '1991'], 'answer': '1989'},
            {'question': 'Who was the first human to journey into outer space?', 'options': ['Neil Armstrong', 'Yuri Gagarin', 'John Glenn'], 'answer': 'Yuri Gagarin'},
            {'question': 'Which treaty ended World War I?', 'options': ['Treaty of Paris', 'Treaty of Versailles', 'Treaty of Vienna'], 'answer': 'Treaty of Versailles'},
            {'question': 'Who was the last Emperor of China?', 'options': ['Sun Yat-sen', 'Puyi', 'Chiang Kai-shek'], 'answer': 'Puyi'},
        ],
    },
    'Geography': {
        'easy': [
            {'question': 'What is the capital of France?', 'options': ['Berlin', 'Madrid', 'Paris'], 'answer': 'Paris'},
            {'question': 'Which continent is the Sahara Desert located on?', 'options': ['Asia', 'Africa', 'Australia'], 'answer': 'Africa'},
            {'question': 'What is the largest ocean on Earth?', 'options': ['Atlantic Ocean', 'Indian Ocean', 'Pacific Ocean'], 'answer': 'Pacific Ocean'},
            {'question': 'Which country is known as the Land of the Rising Sun?', 'options': ['China', 'Japan', 'Thailand'], 'answer': 'Japan'},
            {'question': 'What is the capital of Australia?', 'options': ['Sydney', 'Canberra', 'Melbourne'], 'answer': 'Canberra'},
        ],
        'medium': [
            {'question': 'What is the longest river in the world?', 'options': ['Nile', 'Amazon', 'Yangtze'], 'answer': 'Amazon'},
            {'question': 'Which country has the largest population?', 'options': ['India', 'USA', 'China'], 'answer': 'China'},
            {'question': 'What is the smallest continent by land area?', 'options': ['Europe', 'Australia', 'South America'], 'answer': 'Australia'},
            {'question': 'Which desert is the largest hot desert in the world?', 'options': ['Sahara', 'Gobi', 'Arabian'], 'answer': 'Sahara'},
            {'question': 'What is the capital of Canada?', 'options': ['Toronto', 'Ottawa', 'Vancouver'], 'answer': 'Ottawa'},
        ],
        'hard': [
            {'question': 'Which country is home to the Great Barrier Reef?', 'options': ['Australia', 'Mexico', 'Brazil'], 'answer': 'Australia'},
            {'question': 'What is the smallest country in the world?', 'options': ['Monaco', 'Vatican City', 'San Marino'], 'answer': 'Vatican City'},
            {'question': 'Which country has the most islands?', 'options': ['Indonesia', 'Norway', 'Sweden'], 'answer': 'Sweden'},
            {'question': 'What is the deepest point in the world’s oceans?', 'options': ['Mariana Trench', 'Tonga Trench', 'Java Trench'], 'answer': 'Mariana Trench'},
            {'question': 'Which mountain range is the longest in the world?', 'options': ['Andes', 'Himalayas', 'Rockies'], 'answer': 'Andes'},
        ],
    },
    'Literature': {
        'easy': [
            {'question': 'Who wrote "Romeo and Juliet"?', 'options': ['William Shakespeare', 'Mark Twain', 'Charles Dickens'], 'answer': 'William Shakespeare'},
            {'question': 'What is the name of the wizarding school in "Harry Potter"?', 'options': ['Hogwarts', 'Beauxbatons', 'Durmstrang'], 'answer': 'Hogwarts'},
            {'question': 'Who wrote "The Cat in the Hat"?', 'options': ['Dr. Seuss', 'Roald Dahl', 'J.K. Rowling'], 'answer': 'Dr. Seuss'},
            {'question': 'Who wrote "The Hobbit"?', 'options': ['J.R.R. Tolkien', 'C.S. Lewis', 'J.K. Rowling'], 'answer': 'J.R.R. Tolkien'},
            {'question': 'Who is the author of "Charlotte’s Web"?', 'options': ['E.B. White', 'Roald Dahl', 'Lewis Carroll'], 'answer': 'E.B. White'},
        ],
        'medium': [
            {'question': 'Who wrote "1984"?', 'options': ['Aldous Huxley', 'George Orwell', 'J.K. Rowling'], 'answer': 'George Orwell'},
            {'question': 'Who is the author of "Pride and Prejudice"?', 'options': ['Jane Austen', 'Emily Brontë', 'Mary Shelley'], 'answer': 'Jane Austen'},
            {'question': 'Who wrote "Moby-Dick"?', 'options': ['Herman Melville', 'Mark Twain', 'Nathaniel Hawthorne'], 'answer': 'Herman Melville'},
            {'question': 'Who wrote "The Catcher in the Rye"?', 'options': ['J.D. Salinger', 'F. Scott Fitzgerald', 'Ernest Hemingway'], 'answer': 'J.D. Salinger'},
            {'question': 'Who wrote "The Great Gatsby"?', 'options': ['Ernest Hemingway', 'F. Scott Fitzgerald', 'William Faulkner'], 'answer': 'F. Scott Fitzgerald'},
        ],
        'hard': [
            {'question': 'What is the name of the epic poem written by Homer?', 'options': ['The Iliad', 'Beowulf', 'The Aeneid'], 'answer': 'The Iliad'},
            {'question': 'Who wrote "The Divine Comedy"?', 'options': ['Dante Alighieri', 'Geoffrey Chaucer', 'Virgil'], 'answer': 'Dante Alighieri'},
            {'question': 'Who wrote "War and Peace"?', 'options': ['Leo Tolstoy', 'Fyodor Dostoevsky', 'Alexander Pushkin'], 'answer': 'Leo Tolstoy'},
            {'question': 'Who is the author of "One Hundred Years of Solitude"?', 'options': ['Gabriel Garcia Marquez', 'Jorge Luis Borges', 'Mario Vargas Llosa'], 'answer': 'Gabriel Garcia Marquez'},
            {'question': 'Who wrote "Crime and Punishment"?', 'options': ['Fyodor Dostoevsky', 'Leo Tolstoy', 'Anton Chekhov'], 'answer': 'Fyodor Dostoevsky'},
        ],
    }
}

def quiz_game():
    print("Welcome to the Quiz Game!")
    print("Choose a topic:")
    topics = list(quiz_data.keys())
    
    for i, topic in enumerate(topics, start=1):
        print(f"{i}. {topic}")
    
    topic_choice = int(input("Enter the number of your chosen topic: ")) - 1
    selected_topic = topics[topic_choice]
    
    print(f"You selected {selected_topic}.")
    
    print("Select a difficulty level: easy, medium, hard")
    difficulty = input("Enter difficulty level: ").lower()
    
    questions = quiz_data[selected_topic][difficulty]
    random.shuffle(questions)
    
    score = 0
    
    for i, question in enumerate(questions, start=1):
        print(f"Question {i}: {question['question']}")
        for j, option in enumerate(question['options'], start=1):
            print(f"{j}. {option}")
        
        answer = int(input("Enter the number of your answer: ")) - 1
        selected_answer = question['options'][answer]
        
        if selected_answer == question['answer']:
            print("Correct!")
            score += 1
        else:
            print(f"Incorrect! The correct answer is {question['answer']}.")
        print()
    
    print(f"Quiz Over! Your final score is {score}/{len(questions)}.")

# Run the quiz game
quiz_game()
# Out:
# Welcome to the Quiz Game!
# Choose a topic:
# 1. Math
# 2. Science
# 3. History
# 4. Geography
# 5. Literature
# Enter the number of your chosen topic: 1
# You selected Math.
# Select a difficulty level: easy, medium, hard
# Enter difficulty level: hard
# Question 1: What is 25^2?
# 1. 625
# 2. 650
# 3. 675
# Enter the number of your answer: 1
# Correct!
#
# Question 2: What is 13^2?
# 1. 169
# 2. 144
# 3. 121
# Enter the number of your answer: 1
# Correct!
#
# Question 3: What is the square root of 144?
# 1. 10
# 2. 12
# 3. 14
# Enter the number of your answer: 2
# Correct!
#
# Question 4: What is 22 * 19?
# 1. 418
# 2. 396
# 3. 420
# Enter the number of your answer: 1
# Correct!
#
# Question 5: What is 81^(1/2)?
# 1. 7
# 2. 8
# 3. 9
# Enter the number of your answer: 3
# Correct!
#
# Quiz Over! Your final score is 5/5.
